# %% [markdown]
# <a href="https://colab.research.google.com/github/soumya-1313/Scikit_learn/blob/main/SVM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ***SVM***
# 1. small datset and cpmplex ones
# 2. maximum marginal classifier
# 3. soft margins

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets

# %%
iris=datasets.load_iris()

# %%
x=iris.data
y=iris.target

# %%
names=iris.target_names
print(names)
# Out:
# ['setosa' 'versicolor' 'virginica']

# %%
print(x.shape)
print(y.shape)
# Out:
# (150, 4)
# (150,)

# %%
df=pd.DataFrame(x,columns=iris.feature_names)
df['species']=iris.target
df['species']=df['species'].replace(to_replace=[0,1,2],value=['setosa','versicolor','virginica'])
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#   species
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %% [markdown]
# # ***EDA***

# %%
import seaborn as sns
sns.pairplot(df,hue='species',palette='Set2')

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (120, 4)
# (30, 4)
# (120,)
# (30,)

# %%
from sklearn.svm import SVC
model=SVC()
model.fit(x_train,y_train)
# Out:
# SVC()

# %%
pred=model.predict(x_test)
pred
# Out:
# array([0, 1, 1, 0, 2, 1, 2, 0, 0, 2, 1, 0, 2, 1, 1, 0, 1, 1, 0, 0, 1, 1,
#        2, 0, 2, 1, 0, 0, 1, 2])

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
accuracy_score(y_test,pred)
# Out:
# 0.9666666666666667

# %%
confusion_matrix(y_test,pred)
# Out:
# array([[11,  0,  0],
#        [ 0, 12,  1],
#        [ 0,  0,  6]])

# %%
rbf_svm=SVC(kernel='rbf')
rbf_svm.fit(x_train,y_train)
# Out:
# SVC()

# %%
rbf=rbf_svm.predict(x_test)
rbf
# Out:
# array([0, 1, 1, 0, 2, 1, 2, 0, 0, 2, 1, 0, 2, 1, 1, 0, 1, 1, 0, 0, 1, 1,
#        2, 0, 2, 1, 0, 0, 1, 2])

# %%
accuracy_score(y_test,rbf)
# Out:
# 0.9666666666666667
